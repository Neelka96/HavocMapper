# %% [markdown]
# # Starter API Access Tunnel
# ---

# %% [markdown]
# ## Imports

# %%
# Dependencies
import datetime as dt
import requests
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt

# %%
fema_decl = pd.read_csv('DisasterDeclarationsSummaries.csv', low_memory = False)
fema_decl.tail(25)
# Out:
#       femaDeclarationString  disasterNumber state declarationType  \
# 67331              DR-30-IN              30    IN              DR
# 67332              DR-29-SC              29    SC              DR
# 67333              DR-28-NC              28    NC              DR
# 67334              DR-27-NM              27    NM              DR
# 67335              DR-26-NY              26    NY              DR
# 67336              DR-25-CT              25    CT              DR
# 67337              DR-24-ME              24    ME              DR
# 67338              DR-23-RI              23    RI              DR
# 67339              DR-22-MA              22    MA              DR
# 67340              DR-21-WV              21    WV              DR
# 67341              DR-20-SD              20    SD              DR
# 67342              DR-19-NV              19    NV              DR
# 67343              DR-18-TX              18    TX              DR
# 67344              DR-17-IA              17    IA              DR
# 67345              DR-16-GA              16    GA              DR
# 67346              DR-15-CA              15    CA              DR
# 67347              DR-14-MS              14    MS              DR
# 67348              DR-13-AK              13    AK              DR
# 67349              DR-12-FL              12    FL              DR
# 67350              DR-11-NH              11    NH              DR
# 67351               DR-9-TX               9    TX              DR
# 67352               DR-8-IA               8    IA              DR
# 67353               DR-7-MA               7    MA              DR
# 67354               DR-2-TX               2    TX              DR
# 67355               DR-1-GA               1    GA              DR
#
#                 declarationDate  fyDeclared incidentType  \
# 67331  1954-10-26T00:00:00.000Z        1955        Flood
# 67332  1954-10-17T00:00:00.000Z        1955    Hurricane
# 67333  1954-10-17T00:00:00.000Z        1955    Hurricane
# 67334  1954-10-13T00:00:00.000Z        1955        Flood
# 67335  1954-10-07T00:00:00.000Z        1955    Hurricane
# 67336  1954-09-17T00:00:00.000Z        1954    Hurricane
# 67337  1954-09-13T00:00:00.000Z        1954    Hurricane
# 67338  1954-09-02T00:00:00.000Z        1954    Hurricane
# 67339  1954-09-02T00:00:00.000Z        1954    Hurricane
# 67340  1954-08-04T00:00:00.000Z        1954        Flood
# 67341  1954-07-31T00:00:00.000Z        1954        Flood
# 67342  1954-07-14T00:00:00.000Z        1954   Earthquake
# 67343  1954-07-01T00:00:00.000Z        1954        Flood
# 67344  1954-06-23T00:00:00.000Z        1954        Flood
# 67345  1954-03-17T00:00:00.000Z        1954      Tornado
# 67346  1954-02-05T00:00:00.000Z        1954        Flood
# 67347  1953-12-06T00:00:00.000Z        1954      Tornado
# 67348  1953-10-30T00:00:00.000Z        1954        Other
# 67349  1953-10-22T00:00:00.000Z        1954        Flood
# 67350  1953-07-02T00:00:00.000Z        1953         Fire
# 67351  1953-06-19T00:00:00.000Z        1953        Flood
# 67352  1953-06-11T00:00:00.000Z        1953        Flood
# 67353  1953-06-11T00:00:00.000Z        1953      Tornado
# 67354  1953-05-15T00:00:00.000Z        1953      Tornado
# 67355  1953-05-02T00:00:00.000Z        1953      Tornado
#
#                declarationTitle  ihProgramDeclared  iaProgramDeclared  ...  \
# 67331                     FLOOD                  0                  1  ...
# 67332                 HURRICANE                  0                  1  ...
# 67333                 HURRICANE                  0                  1  ...
# 67334                     FLOOD                  0                  1  ...
# 67335                HURRICANES                  0                  1  ...
# 67336                HURRICANES                  0                  1  ...
# 67337                HURRICANES                  0                  1  ...
# 67338                HURRICANES                  0                  1  ...
# 67339                HURRICANES                  0                  1  ...
# 67340                     FLOOD                  0                  1  ...
# 67341                     FLOOD                  0                  1  ...
# 67342                EARTHQUAKE                  0                  1  ...
# 67343                     FLOOD                  0                  1  ...
# 67344                     FLOOD                  0                  1  ...
# 67345                   TORNADO                  0                  1  ...
# 67346           FLOOD & EROSION                  0                  1  ...
# 67347                   TORNADO                  0                  1  ...
# 67348           SEVERE HARDSHIP                  0                  1  ...
# 67349                     FLOOD                  0                  1  ...
# 67350               FOREST FIRE                  0                  1  ...
# 67351                     FLOOD                  0                  1  ...
# 67352                     FLOOD                  0                  1  ...
# 67353                   TORNADO                  0                  1  ...
# 67354  TORNADO & HEAVY RAINFALL                  0                  1  ...
# 67355                   TORNADO                  0                  1  ...
#
#        placeCode  designatedArea declarationRequestNumber lastIAFilingDate  \
# 67331          0       Statewide                    54018              NaN
# 67332          0       Statewide                    54015              NaN
# 67333          0       Statewide                    54014              NaN
# 67334          0       Statewide                    54017              NaN
# 67335          0       Statewide                    54012              NaN
# 67336          0       Statewide                    54013              NaN
# 67337          0       Statewide                    54011              NaN
# 67338          0       Statewide                    54009              NaN
# 67339          0       Statewide                    54008              NaN
# 67340          0       Statewide                    54007              NaN
# 67341          0       Statewide                    54005              NaN
# 67342          0       Statewide                    54010              NaN
# 67343          0       Statewide                    54004              NaN
# 67344          0       Statewide                    54006              NaN
# 67345          0       Statewide                    54003              NaN
# 67346          0       Statewide                    54016              NaN
# 67347          0       Statewide                    53014              NaN
# 67348          0       Statewide                    53012              NaN
# 67349          0       Statewide                    53015              NaN
# 67350          0       Statewide                    53011              NaN
# 67351          0       Statewide                    53010              NaN
# 67352          0       Statewide                    53008              NaN
# 67353          0       Statewide                    53009              NaN
# 67354          0       Statewide                    53003              NaN
# 67355          0       Statewide                    53013              NaN
#
#       incidentId  region  designatedIncidentTypes               lastRefresh  \
# 67331      54018       5                      NaN  2024-08-27T18:22:14.800Z
# 67332      54015       4                        F  2024-08-27T18:22:14.800Z
# 67333      54014       4                        F  2024-08-27T18:22:14.800Z
# 67334      54017       6                      NaN  2024-08-27T18:22:14.800Z
# 67335      54012       2                        F  2024-08-27T18:22:14.800Z
# 67336      54013       1                        F  2024-08-27T18:22:14.800Z
# 67337      54011       1                        F  2024-08-27T18:22:14.800Z
# 67338      54009       1                        F  2024-08-27T18:22:14.800Z
# 67339      54008       1                        F  2024-08-27T18:22:14.800Z
# 67340      54007       3                      NaN  2024-08-27T18:22:14.800Z
# 67341      54005       8                      NaN  2024-08-27T18:22:14.800Z
# 67342      54010       9                      NaN  2024-08-27T18:22:14.800Z
# 67343      54004       6                      NaN  2024-08-27T18:22:14.800Z
# 67344      54006       7                      NaN  2024-08-27T18:22:14.800Z
# 67345      54003       4                      NaN  2024-08-27T18:22:14.800Z
# 67346      54016       9                      NaN  2024-08-27T18:22:14.800Z
# 67347      53014       4                      NaN  2024-08-27T18:22:14.800Z
# 67348      53012      10                      NaN  2024-08-27T18:22:14.800Z
# 67349      53015       4                      NaN  2024-08-27T18:22:14.800Z
# 67350      53011       1                      NaN  2024-08-27T18:22:14.800Z
# 67351      53010       6                      NaN  2024-08-27T18:22:14.800Z
# 67352      53008       7                      NaN  2024-08-27T18:22:14.800Z
# 67353      53009       1                      NaN  2024-08-27T18:22:14.800Z
# 67354      53003       6                        W  2024-08-27T18:22:14.800Z
# 67355      53013       4                      NaN  2024-08-27T18:22:14.800Z
#
#                                            hash  \
# 67331  e0a086cad35338812c8b78e67c45961bd5893f00
# 67332  e8f926070bf3e2a700ed4802523e59d5df71f6c6
# 67333  25a7536c097742b85da6757d16f03720d68044f2
# 67334  6791ce4c16f606fb5ff42c90f4a2ff78bfdf0400
# 67335  54fa0c74e76fc447b917be88576404be8a9322b4
# 67336  de950b453efae6ca68df43b28734d2439376b083
# 67337  5fd08f98ee48a10787d6ca70e31cb40a4790dac5
# 67338  c80457578b3e3cf2732d1d3d7fda231981cfd51b
# 67339  4be5c5403c4e310e041dbf82643ceaee6fb2851f
# 67340  59d0c5dec67d6d294f0029cca3b3ffd93fb6dc30
# 67341  a9851b180992566f93eb03c62c77f28b4521dc6e
# 67342  78f21b21ca02c51a4e55275c58577c2b650b735d
# 67343  6dbf3a98b6e7951d621bd759691d0f6f6a68ad69
# 67344  8233ddf3dee3ab2c8729a8ecfa5ae91c1b4e24fb
# 67345  ff5b95688ad514a044c96ab554e8270bd0b994c7
# 67346  bb406aed85108d8f443b66391a201ec1dc536b19
# 67347  7950cb174196603cbf9da7bed90f0cea06fcbc37
# 67348  9c2d55e534115516cf862eeed47585d695cd1e24
# 67349  acd9dedcbf3a526b641416f31058b9288eff01b9
# 67350  34dd6e303cd522fb2a21ac3386f6bd36d0ab9a87
# 67351  2488a86cd6660a72865d1e6da2b16eac37753a33
# 67352  a051dd98c34a0ec2485d0f6b5b11d4d93509ad88
# 67353  b720724cfb17afaba95e73a92fdf09b1fd6d0e5f
# 67354  8a8bc885c003cb873c201bb6a3a2771a6d84efb1
# 67355  413ff808d79f08a6710f6b78f361d5a7de692711
#
#                                          id
# 67331  5a8c00ec-1c5b-4b92-9701-bed808f7c8e7
# 67332  eb746761-aa18-438a-8458-0712bd9b81c1
# 67333  831fb666-2973-446f-966c-75290c659776
# 67334  c5b57cc5-10f9-4d39-9326-60b8c793f924
# 67335  194e60b9-e71c-45a3-a5be-09ff7310673c
# 67336  9427c8c0-2b51-4c5b-a9df-fed63989753d
# 67337  232bc345-c512-479a-8deb-ce1e9b221c1b
# 67338  8651012e-0635-4b0e-acca-727176e3acc8
# 67339  b4aa518d-6953-45c5-9ef9-5e0a6ec5ec53
# 67340  a584433f-5362-47c1-b26b-201ff43f3a49
# 67341  622f21a9-39eb-47aa-b455-52780a5e317c
# 67342  afa847c6-f72c-46bb-a604-0ad57bb18682
# 67343  28d42574-2eaa-49b9-9db4-2b31507a45cd
# 67344  6ac44920-f942-4273-bd62-f441ccc06e7e
# 67345  0e461c0c-cb9b-4fd8-b5a0-ff843ce407a6
# 67346  de6f0ab8-5a0d-4c78-b70e-8d522d629747
# 67347  3fa605b7-48ba-4fd9-afdc-5de34fe6ece1
# 67348  353cdf38-9ad2-40cd-b92a-58976c13236f
# 67349  728c3d8d-3b58-4b18-8320-ffe527ddbc68
# 67350  372405d1-242d-4f9c-a5f7-cab71e819116
# 67351  6ef68fa6-5889-466b-9e3b-ee4c06da0876
# 67352  f100b5c1-0f3f-4c3d-ad3c-50040e98ed8d
# 67353  fca83efc-524a-45a0-ac98-2d43b954a5ea
# 67354  ff821327-6b90-4246-b19f-fff8c4b288a8
# 67355  8943dfcf-9786-4e51-8889-d62014034bb2
#
# [25 rows x 28 columns]

# %%
# Removing unwanted/unusable columns
fema_decl_clean = fema_decl[
    [
        'disasterNumber', 'declarationRequestNumber', 'declarationTitle', 'incidentType', 
        'declarationType', 'designatedArea', 'state', 'region', 'declarationDate', 
        'incidentBeginDate', 'tribalRequest', 'ihProgramDeclared', 'iaProgramDeclared', 
        'paProgramDeclared', 'hmProgramDeclared'
    ]
].copy()
fema_decl_clean['declarationDate'] = fema_decl_clean[
    'declarationDate'
    ].str.slice_replace(10)
fema_decl_clean['incidentBeginDate'] = fema_decl_clean[
    'incidentBeginDate'
    ].str.slice_replace(10)
fema_decl_clean
# Out:
#        disasterNumber  declarationRequestNumber          declarationTitle  \
# 0                5530                     24123           GOLD RANCH FIRE
# 1                5529                     24122            LEE FALLS FIRE
# 2                5528                     24116             ELK LANE FIRE
# 3                5527                     24111      MILE MARKER 132 FIRE
# 4                5522                     24102                BOREL FIRE
# ...               ...                       ...                       ...
# 67351               9                     53010                     FLOOD
# 67352               8                     53008                     FLOOD
# 67353               7                     53009                   TORNADO
# 67354               2                     53003  TORNADO & HEAVY RAINFALL
# 67355               1                     53013                   TORNADO
#
#       incidentType declarationType       designatedArea state  region  \
# 0             Fire              FM      Washoe (County)    NV       9
# 1             Fire              FM  Washington (County)    OR      10
# 2             Fire              FM   Jefferson (County)    OR      10
# 3             Fire              FM   Deschutes (County)    OR      10
# 4             Fire              FM        Kern (County)    CA       9
# ...            ...             ...                  ...   ...     ...
# 67351        Flood              DR            Statewide    TX       6
# 67352        Flood              DR            Statewide    IA       7
# 67353      Tornado              DR            Statewide    MA       1
# 67354      Tornado              DR            Statewide    TX       6
# 67355      Tornado              DR            Statewide    GA       4
#
#       declarationDate incidentBeginDate  tribalRequest  ihProgramDeclared  \
# 0          2024-08-12        2024-08-11              0                  0
# 1          2024-08-09        2024-08-08              0                  0
# 2          2024-08-06        2024-08-04              0                  0
# 3          2024-08-02        2024-08-02              0                  0
# 4          2024-07-27        2024-07-25              0                  0
# ...               ...               ...            ...                ...
# 67351      1953-06-19        1953-06-19              0                  0
# 67352      1953-06-11        1953-06-11              0                  0
# 67353      1953-06-11        1953-06-11              0                  0
# 67354      1953-05-15        1953-05-15              0                  0
# 67355      1953-05-02        1953-05-02              0                  0
#
#        iaProgramDeclared  paProgramDeclared  hmProgramDeclared
# 0                      0                  1                  1
# 1                      0                  1                  1
# 2                      0                  1                  1
# 3                      0                  1                  1
# 4                      0                  1                  1
# ...                  ...                ...                ...
# 67351                  1                  1                  1
# 67352                  1                  1                  1
# 67353                  1                  1                  1
# 67354                  1                  1                  1
# 67355                  1                  1                  1
#
# [67356 rows x 15 columns]

# %%
# Unique FEMA Disaster Types
disaster_types = fema_decl_clean['incidentType'].unique()
pprint(disaster_types)
# Out:
# array(['Fire', 'Severe Storm', 'Straight-Line Winds', 'Flood',
#        'Winter Storm', 'Hurricane', 'Tornado', 'Mud/Landslide',
#        'Tropical Storm', 'Snowstorm', 'Earthquake', 'Coastal Storm',
#        'Other', 'Severe Ice Storm', 'Biological', 'Dam/Levee Break',
#        'Typhoon', 'Volcanic Eruption', 'Freezing', 'Toxic Substances',
#        'Chemical', 'Terrorist', 'Drought', 'Human Cause',
#        'Fishing Losses', 'Tsunami'], dtype=object)

# %%
disaster_natural = pd.DataFrame(
    {
        'incidentType': [
            'Fire', 'Severe Storm', 'Straight-Line Winds', 
            'Flood', 'Winter Storm', 'Hurricane', 'Tornado',
            'Mud/Landslide', 'Tropical Storm', 'Snowstorm', 
            'Earthquake', 'Coastal Storm', 'Severe Ice Storm', 
            'Typhoon', 'Volcanic Eruption', 'Freezing', 
            'Drought', 'Tsunami'
        ]
    }
)

# %%
# Filter for just natural disaster types
fema_disasters = pd.merge(fema_decl_clean, disaster_natural, how = 'right', on = 'incidentType')
# fema_disasters = fema_disasters.rename(
#     columns = {
#         'disasterNumber': 'disaster_number', 'designatedArea': 'area',
#         'declarationRequestNumber': 'request_number', 'declarationTitle': 'title',
#         'incidentType': 'disaster_type''

#     }
# )
display(fema_disasters)
# Out:
#        disasterNumber  declarationRequestNumber      declarationTitle  \
# 0                5530                     24123       GOLD RANCH FIRE
# 1                5529                     24122        LEE FALLS FIRE
# 2                5528                     24116         ELK LANE FIRE
# 3                5527                     24111  MILE MARKER 132 FIRE
# 4                5522                     24102            BOREL FIRE
# ...               ...                       ...                   ...
# 59096            1967                     11042         TSUNAMI WAVES
# 59097            1967                     11042         TSUNAMI WAVES
# 59098            1964                     11029    TSUNAMI WAVE SURGE
# 59099            1964                     11029    TSUNAMI WAVE SURGE
# 59100            1964                     11029    TSUNAMI WAVE SURGE
#
#       incidentType declarationType       designatedArea state  region  \
# 0             Fire              FM      Washoe (County)    NV       9
# 1             Fire              FM  Washington (County)    OR      10
# 2             Fire              FM   Jefferson (County)    OR      10
# 3             Fire              FM   Deschutes (County)    OR      10
# 4             Fire              FM        Kern (County)    CA       9
# ...            ...             ...                  ...   ...     ...
# 59096      Tsunami              DR    Honolulu (County)    HI       9
# 59097      Tsunami              DR        Maui (County)    HI       9
# 59098      Tsunami              DR        Coos (County)    OR      10
# 59099      Tsunami              DR       Curry (County)    OR      10
# 59100      Tsunami              DR     Lincoln (County)    OR      10
#
#       declarationDate incidentBeginDate  tribalRequest  ihProgramDeclared  \
# 0          2024-08-12        2024-08-11              0                  0
# 1          2024-08-09        2024-08-08              0                  0
# 2          2024-08-06        2024-08-04              0                  0
# 3          2024-08-02        2024-08-02              0                  0
# 4          2024-07-27        2024-07-25              0                  0
# ...               ...               ...            ...                ...
# 59096      2011-04-08        2011-03-11              0                  0
# 59097      2011-04-08        2011-03-11              0                  0
# 59098      2011-03-25        2011-03-11              0                  0
# 59099      2011-03-25        2011-03-11              0                  0
# 59100      2011-03-25        2011-03-11              0                  0
#
#        iaProgramDeclared  paProgramDeclared  hmProgramDeclared
# 0                      0                  1                  1
# 1                      0                  1                  1
# 2                      0                  1                  1
# 3                      0                  1                  1
# 4                      0                  1                  1
# ...                  ...                ...                ...
# 59096                  0                  1                  1
# 59097                  0                  1                  1
# 59098                  0                  1                  1
# 59099                  0                  1                  1
# 59100                  0                  1                  1
#
# [59101 rows x 15 columns]

# %%
# Counts of declaration types 
# DR = Major Disasters, EM = Emergency Declatation, FM = Fire Management)
# For more info see README (in progress)
fema_disasters['declarationType'].value_counts()
# Out:
# declarationType
# DR    41116
# EM    15991
# FM     1994
# Name: count, dtype: int64

# %%
# Counts of natural disaster types
fema_disasters['incidentType'].value_counts()
# Out:
# incidentType
# Severe Storm           18399
# Hurricane              13721
# Flood                  11093
# Fire                    3759
# Snowstorm               3707
# Severe Ice Storm        2942
# Tornado                 1623
# Drought                 1292
# Tropical Storm          1047
# Coastal Storm            637
# Freezing                 301
# Earthquake               228
# Typhoon                  130
# Winter Storm             117
# Volcanic Eruption         51
# Mud/Landslide             43
# Tsunami                    9
# Straight-Line Winds        2
# Name: count, dtype: int64

# %%
# Validating no NaNs
fema_disasters.count()
# Out:
# disasterNumber              59101
# declarationRequestNumber    59101
# declarationTitle            59101
# incidentType                59101
# declarationType             59101
# designatedArea              59101
# state                       59101
# region                      59101
# declarationDate             59101
# incidentBeginDate           59101
# tribalRequest               59101
# ihProgramDeclared           59101
# iaProgramDeclared           59101
# paProgramDeclared           59101
# hmProgramDeclared           59101
# dtype: int64

# %%
# Filter: Natural disasters per State
fema_disasters['state'].value_counts()
# Out:
# state
# TX    4779
# FL    2635
# KY    2554
# MO    2534
# LA    2398
# GA    2333
# VA    2308
# OK    2305
# NC    2110
# PR    1947
# MS    1777
# IA    1719
# KS    1607
# AL    1603
# CA    1557
# TN    1532
# AR    1472
# MN    1406
# NE    1336
# ND    1280
# IN    1279
# NY    1278
# SD    1181
# WV    1148
# PA    1118
# IL    1109
# OH    1102
# SC    1039
# WA     902
# WI     725
# MI     595
# NJ     556
# OR     536
# CO     531
# MT     507
# ME     426
# MD     399
# NM     380
# VT     377
# MA     365
# NH     300
# ID     276
# AZ     271
# CT     245
# AK     211
# NV     198
# UT     183
# RI     106
# HI      97
# WY      86
# VI      79
# MP      67
# AS      66
# MH      53
# DE      47
# FM      31
# GU      20
# DC      19
# PW       1
# Name: count, dtype: int64

# %%
# Filter: Natural disasters per hit area
fema_disasters['designatedArea'].value_counts()
# Out:
# designatedArea
# Washington (County)                          510
# Jefferson (County)                           462
# Statewide                                    450
# Jackson (County)                             450
# Franklin (County)                            441
#                                             ...
# Southern Ute Indian Reservation                1
# Ute Mountain Indian Reservation (Also NM)      1
# Nondalton (ANV/ANVSA)                          1
# Salt River Pima-Maricopa Indian Community      1
# Namorik (County-equivalent)                    1
# Name: count, Length: 2201, dtype: int64

# %%
grouped_data = fema_decl.groupby(['incidentType', 'state', 'declarationTitle']).size().reset_index(name='count')
grouped_data.head(15)
# Out:
#    incidentType state   declarationTitle  count
# 0    Biological    AK          COVID-19      37
# 1    Biological    AK  COVID-19 PANDEMIC     84
# 2    Biological    AL          COVID-19      69
# 3    Biological    AL  COVID-19 PANDEMIC     70
# 4    Biological    AR          COVID-19      76
# 5    Biological    AR  COVID-19 PANDEMIC     76
# 6    Biological    AS          COVID-19       5
# 7    Biological    AS  COVID-19 PANDEMIC      5
# 8    Biological    AZ           COVID-19     36
# 9    Biological    AZ  COVID-19 PANDEMIC     37
# 10   Biological    CA           COVID-19     58
# 11   Biological    CA  COVID-19 PANDEMIC     58
# 12   Biological    CO           COVID-19     66
# 13   Biological    CO  COVID-19 PANDEMIC     66
# 14   Biological    CT          COVID-19       9

# %%
disaster_by_state = fema_decl.groupby('state').size().reset_index(name='total_disasters')
disaster_by_state = disaster_by_state.sort_values(by='total_disasters', ascending=False)
disaster_by_state
# Out:
#    state  total_disasters
# 50    TX             5350
# 20    KY             2796
# 10    FL             2791
# 28    MO             2764
# 12    GA             2653
# 21    LA             2589
# 52    VA             2585
# 41    OK             2546
# 32    NC             2317
# 44    PR             2104
# 30    MS             1945
# 15    IA             1922
# 19    KS             1842
# 1     AL             1742
# 49    TN             1723
# 5     CA             1683
# 2     AR             1624
# 27    MN             1621
# 34    NE             1541
# 39    NY             1537
# 48    SD             1467
# 18    IN             1464
# 33    ND             1397
# 17    IL             1313
# 40    OH             1292
# 57    WV             1267
# 43    PA             1252
# 47    SC             1133
# 24    ME             1065
# 55    WA             1015
# 56    WI              892
# 26    MI              805
# 6     CO              664
# 31    MT              641
# 42    OR              627
# 36    NJ              626
# 37    NM              531
# 23    MD              447
# 22    MA              414
# 54    VT              405
# 16    ID              369
# 4     AZ              344
# 0     AK              336
# 35    NH              320
# 38    NV              286
# 7     CT              266
# 51    UT              255
# 58    WY              135
# 46    RI              123
# 14    HI              108
# 53    VI               87
# 3     AS               76
# 29    MP               76
# 25    MH               53
# 9     DE               53
# 11    FM               31
# 8     DC               23
# 13    GU               22
# 45    PW                1

# %%
disaster_by_type = fema_decl.groupby(['state', 'incidentType']).size().reset_index(name='count')
disaster_by_type = disaster_by_type.sort_values(by='count', ascending=False)
disaster_by_type.head(25)
# Out:
#     state  incidentType  count
# 185    LA     Hurricane   1450
# 91     FL     Hurricane   1432
# 253    MO  Severe Storm   1399
# 443    TX     Hurricane   1370
# 282    NC     Hurricane   1304
# 440    TX          Fire   1229
# 176    KY  Severe Storm   1156
# 166    KS  Severe Storm   1095
# 369    OK  Severe Storm   1041
# 105    GA     Hurricane   1031
# 396    PR     Hurricane   1024
# 463    VA     Hurricane    877
# 432    TN  Severe Storm    845
# 446    TX  Severe Storm    760
# 261    MS     Hurricane    745
# 134    IA  Severe Storm    744
# 304    NE  Severe Storm    738
# 131    IA         Flood    729
# 240    MN         Flood    719
# 264    MS  Severe Storm    681
# 14     AL     Hurricane    678
# 293    ND         Flood    674
# 157    IN  Severe Storm    668
# 23     AR  Severe Storm    651
# 210    ME    Biological    623

# %%
top_states = disaster_by_state.head(10)
plt.figure(figsize=(12, 6))
plt.bar(top_states['state'], top_states['total_disasters'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Total Disasters')
plt.title('Top 10 States with the Most Natural Disasters')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_disaster_types = disaster_by_type.groupby('incidentType')['count'].sum().reset_index()
top_disaster_types = top_disaster_types.sort_values(by='count', ascending=False).head(10)
plt.figure(figsize=(12, 6))
plt.bar(top_disaster_types['incidentType'], top_disaster_types['count'], color='orange')
plt.xlabel('Disaster Type')
plt.ylabel('Count')
plt.title('Top 10 Most Frequent Disaster Types')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
most_common_disasters = disaster_by_type.loc[
    disaster_by_type.groupby('state')['count'].idxmax()]
most_common_disasters = most_common_disasters.sort_values(by='count', ascending=False)
most_common_disasters
# Out:
#     state  incidentType  count
# 185    LA     Hurricane   1450
# 91     FL     Hurricane   1432
# 253    MO  Severe Storm   1399
# 443    TX     Hurricane   1370
# 282    NC     Hurricane   1304
# 176    KY  Severe Storm   1156
# 166    KS  Severe Storm   1095
# 369    OK  Severe Storm   1041
# 105    GA     Hurricane   1031
# 396    PR     Hurricane   1024
# 463    VA     Hurricane    877
# 432    TN  Severe Storm    845
# 261    MS     Hurricane    745
# 134    IA  Severe Storm    744
# 304    NE  Severe Storm    738
# 240    MN         Flood    719
# 14     AL     Hurricane    678
# 293    ND         Flood    674
# 157    IN  Severe Storm    668
# 23     AR  Severe Storm    651
# 210    ME    Biological    623
# 412    SC     Hurricane    621
# 360    OH  Severe Storm    566
# 422    SD  Severe Storm    486
# 511    WV  Severe Storm    476
# 46     CA          Fire    476
# 349    NY  Severe Storm    381
# 384    PA         Flood    349
# 147    IL         Flood    325
# 500    WI  Severe Storm    293
# 490    WA         Flood    291
# 321    NJ     Hurricane    193
# 225    MI    Biological    188
# 376    OR          Fire    174
# 481    VT  Severe Storm    173
# 61     CO         Flood    160
# 328    NM          Fire    152
# 270    MT          Fire    152
# 206    MD     Hurricane    151
# 0      AK    Biological    121
# 313    NH  Severe Storm    120
# 197    MA     Hurricane    108
# 68     CT     Hurricane     96
# 36     AZ          Fire     95
# 137    ID    Biological     93
# 332    NV    Biological     88
# 454    UT         Flood     78
# 472    VI     Hurricane     53
# 258    MP       Typhoon     53
# 514    WY    Biological     48
# 403    RI     Hurricane     43
# 120    HI          Fire     27
# 221    MH       Drought     25
# 31     AS     Hurricane     25
# 99     FM       Typhoon     23
# 82     DE     Hurricane     22
# 117    GU       Typhoon     13
# 76     DC  Severe Storm      9
# 400    PW       Typhoon      1

# %%
top_states_disasters = most_common_disasters.head(10)
states = top_states_disasters['state']
disasters = top_states_disasters['incidentType']
counts = top_states_disasters['count']

plt.figure(figsize=(12, 6))
plt.bar(states, counts, color='violet')
for i, disaster in enumerate(disasters):
    plt.text(i, counts.iloc[i] + 0.5, disaster, ha='center', fontsize=8)
plt.xlabel('State')
plt.ylabel('Number of Disasters')
plt.title('Most Common Natural Disasters in Each Top State', fontsize=16)
plt.xticks(rotation=45)
plt.tight_layout()
plt.xticks(rotation=60, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Geoapify Geocoding API

# %%
geoapify_base = 'https://api.geoapify.com/v1/geocode/search?'
geoapify_params = {
    'apiKey': api_keys.geoapify_key
    }
